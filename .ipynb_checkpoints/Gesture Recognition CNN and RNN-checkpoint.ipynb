# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
from skimage.transform import resize
from imageio import imread
import datetime
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter, ImageEnhance
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
#project_data_path = "C:\\Users\\rakes\\Desktop\\Project_data"
project_data_path = "/home/datasets/Project_data" #uncomment for jarvis/google colab


train_doc = np.random.permutation(open(project_data_path +'/train.csv').readlines())
val_doc = np.random.permutation(open(project_data_path +'/val.csv').readlines())
batch_size = 30 #experiment with the batch size
dim_x, dim_y = 120, 120
images_sequence = range(2,26,2)

# %%
device_name = tf.test.gpu_device_name()
if "GPU" not in device_name:
    print("GPU device not found")
else:
    print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0
# 2023-08-07 19:42:22.913680: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-08-07 19:42:22.913742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 14802 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1d:00.0, compute capability: 7.5

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size, debug=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = images_sequence#create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        t = np.random.permutation(folder_list)
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))
                        
                
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y,z))
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path =  project_data_path + '/train'
val_path = project_data_path + '/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 50# choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative 
test_gen = generator(train_path, train_doc, 1, debug = True)
d = next(test_gen)[0]
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 1

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ### Model 1 CNN+ GRU

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, Dropout, TimeDistributed, Flatten, BatchNormalization, Activation,GlobalAveragePooling2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from tensorflow.keras.layers import LSTM

input_shape = (len(images_sequence), dim_x, dim_y, 3)

#write your model here
model = Sequential()
model.add(TimeDistributed(
     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
 )
model.add(TimeDistributed(
     MaxPooling2D((2,2)))
 )
model.add(BatchNormalization())

model.add(TimeDistributed(
     Conv2D(64, (3,3), activation='relu'))
 )
model.add(TimeDistributed(
     MaxPooling2D((2,2)))
 )
model.add(BatchNormalization())
model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(BatchNormalization())
model.add(GRU(128))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))
# Out:
# 2023-08-07 19:42:32.091758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14802 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1d:00.0, compute capability: 7.5

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = tf.optimizers.Adam(lr=0.01)#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 12, 118, 118, 32)  896
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 12, 59, 59, 32)   0
#  tributed)
#
#  batch_normalization (BatchN  (None, 12, 59, 59, 32)   128
#  ormalization)
#
#  time_distributed_2 (TimeDis  (None, 12, 57, 57, 64)   18496
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 12, 28, 28, 64)   0
#  tributed)
#
#  batch_normalization_1 (Batc  (None, 12, 28, 28, 64)   256
#  hNormalization)
#
#  time_distributed_4 (TimeDis  (None, 12, 64)           0
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 12, 64)           4160
#  tributed)
#
#  batch_normalization_2 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  gru (GRU)                   (None, 128)               74496
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 99,845
# Trainable params: 99,269
# Non-trainable params: 576
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 30
# Epoch 1/50
# 23/23 [==============================] - ETA: 0s - loss: 1.6525 - categorical_accuracy: 0.3609Source path =  /home/datasets/Project_data/val ; batch size = 30
#
# Epoch 00001: saving model to model_init_2023-08-0621_42_03.599930/model-00001-1.65251-0.36087-2.23289-0.19167.h5
# 23/23 [==============================] - 68s 3s/step - loss: 1.6525 - categorical_accuracy: 0.3609 - val_loss: 2.2329 - val_categorical_accuracy: 0.1917 - lr: 0.0100
# Epoch 2/50
# 23/23 [==============================] - ETA: 0s - loss: 1.0720 - categorical_accuracy: 0.4826
# Epoch 00002: saving model to model_init_2023-08-0621_42_03.599930/model-00002-1.07197-0.48261-1.89119-0.16667.h5
# 23/23 [==============================] - 64s 3s/step - loss: 1.0720 - categorical_accuracy: 0.4826 - val_loss: 1.8912 - val_categorical_accuracy: 0.1667 - lr: 0.0100
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 1.0147 - categorical_accuracy: 0.5884
# Epoch 00003: saving model to model_init_2023-08-0621_42_03.599930/model-00003-1.01465-0.58841-1.84624-0.15000.h5
# 23/23 [==============================] - 63s 3s/step - loss: 1.0147 - categorical_accuracy: 0.5884 - val_loss: 1.8462 - val_categorical_accuracy: 0.1500 - lr: 0.0100
# Epoch 4/50
# 23/23 [==============================] - ETA: 0s - loss: 0.9048 - categorical_accuracy: 0.5783
# Epoch 00004: saving model to model_init_2023-08-0621_42_03.599930/model-00004-0.90479-0.57826-1.79614-0.33333.h5
# 23/23 [==============================] - 61s 3s/step - loss: 0.9048 - categorical_accuracy: 0.5783 - val_loss: 1.7961 - val_categorical_accuracy: 0.3333 - lr: 0.0100
# Epoch 5/50
# 23/23 [==============================] - ETA: 0s - loss: 0.
50
# 23/23 [==============================] - ETA: 0s - loss: 0.1393 - categorical_accuracy: 0.9101
# Epoch 00050: saving model to model_init_2023-08-0621_42_03.599930/model-00050-0.13928-0.91014-0.66778-0.60833.h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.1393 - categorical_accuracy: 0.9101 - val_loss: 0.6678 - val_categorical_accuracy: 0.6083 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %% [markdown]
# ### Insights
# - Traning is overfitting and got accuracy of 90% and 60% on validation
# - changing layer by adding drop outs

# %% [markdown]
# ### Model 2 CNN+ GRU

# %%
model = Sequential()
model.add(TimeDistributed(
     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
 )
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Flatten()))

model.add(GRU(128))
model.add(Dropout(0.25))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(5, activation='softmax'))

# %%
optimiser = tf.optimizers.Adam(lr=0.01)#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_6 (TimeDis  (None, 12, 118, 118, 32)  896
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 12, 118, 118, 32)  128
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 12, 59, 59, 32)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 12, 111392)       0
#  tributed)
#
#  gru_1 (GRU)                 (None, 128)               42824448
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 42,842,629
# Trainable params: 42,842,565
# Non-trainable params: 64
# _________________________________________________________________
# None

# %% [markdown]
# ### Traning the model

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 30
# Epoch 1/50
# 2023-08-07 08:23:50.854186: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 23/23 [==============================] - ETA: 0s - loss: 1.6637 - categorical_accuracy: 0.2493Source path =  /home/datasets/Project_data/val ; batch size = 30
#
# Epoch 00001: saving model to model_init_2023-08-0708_22_46.067232/model-00001-1.66372-0.24928-1.64770-0.31667.h5
# 23/23 [==============================] - 70s 3s/step - loss: 1.6637 - categorical_accuracy: 0.2493 - val_loss: 1.6477 - val_categorical_accuracy: 0.3167 - lr: 0.0100
# Epoch 2/50
# 23/23 [==============================] - ETA: 0s - loss: 1.4421 - categorical_accuracy: 0.3261
# Epoch 00002: saving model to model_init_2023-08-0708_22_46.067232/model-00002-1.44214-0.32609-1.80959-0.15000.h5
# 23/23 [==============================] - 65s 3s/step - loss: 1.4421 - categorical_accuracy: 0.3261 - val_loss: 1.8096 - val_categorical_accuracy: 0.1500 - lr: 0.0100
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 1.5076 - categorical_accuracy: 0.3275
# Epoch 00003: saving model to model_init_2023-08-0708_22_46.067232/model-00003-1.50764-0.32754-1.49439-0.19167.h5
# 23/23 [==============================] - 67s 3s/step - loss: 1.5076 - categorical_accuracy: 0.3275 - val_loss: 1.4944 - val_categorical_accuracy: 0.1917 - lr: 0.0100
# Epoch 4/50
# 23/23 [==============================] - ETA: 0s - loss: 1.
50
# 23/23 [==============================] - ETA: 0s - loss: 1.1462 - categorical_accuracy: 0.4580
# Epoch 00047: saving model to model_init_2023-08-0708_22_46.067232/model-00047-1.14616-0.45797-0.96208-0.40833.h5
# 23/23 [==============================] - 70s 3s/step - loss: 1.1462 - categorical_accuracy: 0.4580 - val_loss: 0.9621 - val_categorical_accuracy: 0.4083 - lr: 0.0010
# Epoch 48/50
# 23/23 [==============================] - ETA: 0s - loss: 1.1872 - categorical_accuracy: 0.4420
# Epoch 00048: saving model to model_init_2023-08-0708_22_46.067232/model-00048-1.18721-0.44203-1.00258-0.33333.h5
# 23/23 [==============================] - 65s 3s/step - loss: 1.1872 - categorical_accuracy: 0.4420 - val_loss: 1.0026 - val_categorical_accuracy: 0.3333 - lr: 0.0010
# Epoch 49/50
# 23/23 [==============================] - ETA: 0s - loss: 1.1906 - categorical_accuracy: 0.4580
# Epoch 00049: saving model to model_init_2023-08-0708_22_46.067232/model-00049-1.19063-0.45797-0.97193-0.40000.h5
# 23/23 [==============================] - 70s 3s/step - loss: 1.1906 - categorical_accuracy: 0.4580 - val_loss: 0.9719 - val_categorical_accuracy: 0.4000 - lr: 0.0010
# Epoch 50/50
# 23/23 [==============================] - ETA: 0s - loss: 1.0791 - categorical_accuracy: 0.4928
# Epoch 00050: saving model to model_init_2023-08-0708_22_46.067232/model-00050-1.07906-0.49275-1.03558-0.44167.h5
# 23/23 [==============================] - 63s 3s/step - loss: 1.0791 - categorical_accuracy: 0.4928 - val_loss: 1.0356 - val_categorical_accuracy: 0.4417 - lr: 0.0010

# %% [markdown]
# ### Insights:
# - Adding drop out helped to remove overfitting
# - let's try changing batch_size and epochs

# %%
batch_size = 5
num_epochs = 20
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 5
# Epoch 1/20
# 2023-08-07 17:05:15.445184: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 133/133 [==============================] - ETA: 0s - loss: 1.7675 - categorical_accuracy: 0.3338Source path =  /home/datasets/Project_data/val ; batch size = 5
#
# Epoch 00001: saving model to model_init_2023-08-0717_04_04.539041/model-00001-1.76754-0.33383-2.29649-0.25000.h5
# 133/133 [==============================] - 65s 464ms/step - loss: 1.7675 - categorical_accuracy: 0.3338 - val_loss: 2.2965 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5263 - categorical_accuracy: 0.3278
# Epoch 00002: saving model to model_init_2023-08-0717_04_04.539041/model-00002-1.52627-0.32782-1.93302-0.24000.h5
# 133/133 [==============================] - 61s 462ms/step - loss: 1.5263 - categorical_accuracy: 0.3278 - val_loss: 1.9330 - val_categorical_accuracy: 0.2400 - lr: 0.0100
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 1.4544 - categorical_accuracy: 0.3414
# Epoch 00003: saving model to model_init_2023-08-0717_04_04.539041/model-00003-1.45442-0.34135-1.38120-0.31000.h5
# 133/133 [==============================] - 61s 459ms/step - loss: 1.4544 - categorical_accuracy: 0.3414 - val_loss: 1.3812 - val_categorical_accuracy: 0.3100 - lr: 0.0100
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 1.0547 - categorical_accuracy: 0.5233
# Epoch 00019: saving model to model_init_2023-08-0717_04_04.539041/model-00019-1.05474-0.52331-0.91474-0.58000.h5
# 133/133 [==============================] - 62s 468ms/step - loss: 1.0547 - categorical_accuracy: 0.5233 - val_loss: 0.9147 - val_categorical_accuracy: 0.5800 - lr: 0.0020
# Epoch 20/20
# 133/133 [==============================] - ETA: 0s - loss: 1.0332 - categorical_accuracy: 0.5519
# Epoch 00020: saving model to model_init_2023-08-0717_04_04.539041/model-00020-1.03316-0.55188-1.22012-0.45000.h5
# 133/133 [==============================] - 62s 467ms/step - loss: 1.0332 - categorical_accuracy: 0.5519 - val_loss: 1.2201 - val_categorical_accuracy: 0.4500 - lr: 0.0020

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %% [markdown]
# ### Insights
# - after reducing we can see that 55% and 45% on traning and validation respectively
# - let's try adding augmentation

# %%
images_sequence = range(2,26,2)
def generator(source_path, folder_list, batch_size, debug=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = images_sequence#create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        t = np.random.permutation(folder_list)
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                aug_type = None
                if rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))                        
                
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y,z))
                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                 
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches

# %%
batch_size = 5
num_epochs = 20
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 5
# Epoch 1/20
# 133/133 [==============================] - ETA: 0s - loss: 1.9885 - categorical_accuracy: 0.2120Source path =  /home/datasets/Project_data/val ; batch size = 5
#
# Epoch 00001: saving model to model_init_2023-08-0717_42_21.195077/model-00001-1.98852-0.21203-1.66400-0.23000.h5
# 133/133 [==============================] - 60s 454ms/step - loss: 1.9885 - categorical_accuracy: 0.2120 - val_loss: 1.6640 - val_categorical_accuracy: 0.2300 - lr: 0.0100
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 1.9434 - categorical_accuracy: 0.2015
# Epoch 00002: saving model to model_init_2023-08-0717_42_21.195077/model-00002-1.94340-0.20150-2.03930-0.23000.h5
# 133/133 [==============================] - 60s 454ms/step - loss: 1.9434 - categorical_accuracy: 0.2015 - val_loss: 2.0393 - val_categorical_accuracy: 0.2300 - lr: 0.0100
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 1.7423 - categorical_accuracy: 0.2256
# Epoch 00003: saving model to model_init_2023-08-0717_42_21.195077/model-00003-1.74229-0.22556-1.67509-0.24000.h5
# 133/133 [==============================] - 62s 467ms/step - loss: 1.7423 - categorical_accuracy: 0.2256 - val_loss: 1.6751 - val_categorical_accuracy: 0.2400 - lr: 0.0100
# Epoch 4/20
# 133/133 [==============================] - ETA: 0s - loss: 1.6698 - categorical_accuracy: 0.2316
# Epoch 00004: saving model to model_init_2023-08-0717_42_21.195077/model-00004-1.66982-0.23158-1.66355-0.22000.h5
# 133/133 [==============================] - 62s 473ms/step - loss: 1.6698 - categorical_accuracy: 0.2316 - val_loss: 1.6636 - val_categorical_accuracy: 0.2200 - lr: 0.0100
# Epoch 5/20
# 133/133 [==============================] - ETA: 0s - loss: 1.6738 - categorical_accuracy: 0.2511
# Epoch 00005: saving model to model_init_2023-08-0717_42_21.195077/model-00005-1.67378-0.25113-1.71893-0.29000.h5
# 133/133 [==============================] - 61s 461ms/step - loss: 1.6738 - categorical_accuracy: 0.2511 - val_loss: 1.7189 - val_categorical_accuracy: 0.2900 - lr: 0.0100
# Epoch 6/20
# 133/133 [==============================] - ETA: 0s - loss: 1.6508 - categorical_accuracy: 0.2481
# Epoch 00006: saving model to model_init_2023-08-0717_42_21.195077/model-00006-1.65077-0.24812-1.52109-0.36000.h5
# 133/133 [==============================] - 62s 469ms/step - loss: 1.6508 - categorical_accuracy: 0.2481 - val_loss: 1.5211 - val_categorical_accuracy: 0.3600 - lr: 0.0100
# Epoch 7/20
# 133/133 [==============================] - ETA: 0s - loss: 1.6220 - categorical_accuracy: 0.2496
# Epoch 00007: saving model to model_init_2023-08-0717_42_21.195077/model-00007-1.62203-0.24962-1.62930-0.16000.h5
# Epoch 15/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5478 - categorical_accuracy: 0.2752
# Epoch 00015: saving model to model_init_2023-08-0717_42_21.195077/model-00015-1.54779-0.27519-1.56971-0.21000.h5
# 133/133 [==============================] - 63s 478ms/step - loss: 1.5478 - categorical_accuracy: 0.2752 - val_loss: 1.5697 - val_categorical_accuracy: 0.2100 - lr: 0.0020
# Epoch 16/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5626 - categorical_accuracy: 0.2496
# Epoch 00016: saving model to model_init_2023-08-0717_42_21.195077/model-00016-1.56260-0.24962-1.49956-0.28000.h5
# 133/133 [==============================] - 63s 481ms/step - loss: 1.5626 - categorical_accuracy: 0.2496 - val_loss: 1.4996 - val_categorical_accuracy: 0.2800 - lr: 0.0020
# Epoch 17/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5342 - categorical_accuracy: 0.2812
# Epoch 00017: saving model to model_init_2023-08-0717_42_21.195077/model-00017-1.53417-0.28120-1.50900-0.26000.h5
# 133/133 [==============================] - 62s 472ms/step - loss: 1.5342 - categorical_accuracy: 0.2812 - val_loss: 1.5090 - val_categorical_accuracy: 0.2600 - lr: 0.0020
# Epoch 18/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5779 - categorical_accuracy: 0.2511
# Epoch 00018: saving model to model_init_2023-08-0717_42_21.195077/model-00018-1.57790-0.25113-1.53654-0.28000.h5
# 133/133 [==============================] - 63s 477ms/step - loss: 1.5779 - categorical_accuracy: 0.2511 - val_loss: 1.5365 - val_categorical_accuracy: 0.2800 - lr: 0.0020
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5490 - categorical_accuracy: 0.2617
# Epoch 00019: saving model to model_init_2023-08-0717_42_21.195077/model-00019-1.54895-0.26165-1.50789-0.28000.h5
# 133/133 [==============================] - 63s 480ms/step - loss: 1.5490 - categorical_accuracy: 0.2617 - val_loss: 1.5079 - val_categorical_accuracy: 0.2800 - lr: 0.0020
# Epoch 20/20
# 133/133 [==============================] - ETA: 0s - loss: 1.5420 - categorical_accuracy: 0.2571
# Epoch 00020: saving model to model_init_2023-08-0717_42_21.195077/model-00020-1.54201-0.25714-1.53307-0.29000.h5
# 133/133 [==============================] - 63s 480ms/step - loss: 1.5420 - categorical_accuracy: 0.2571 - val_loss: 1.5331 - val_categorical_accuracy: 0.2900 - lr: 0.0020

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %% [markdown]
# ### Insights
# - clearly by adding augmentation reduced accuracy with layer changes

# %% [markdown]
# ### Model 3 CNN+ GRU by increasing epoch and batch size

# %%
images_sequence = range(2,26,2)
def generator(source_path, folder_list, batch_size, debug=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = images_sequence#create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        t = np.random.permutation(folder_list)
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))                        
                
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y,z))
                 
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
batch_size = 30
num_epochs = 50
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 30
# Epoch 1/50
# 23/23 [==============================] - ETA: 0s - loss: 1.3559 - categorical_accuracy: 0.3319Source path =  /home/datasets/Project_data/val ; batch size = 30
#
# Epoch 00001: saving model to model_init_2023-08-0717_42_21.195077/model-00001-1.35585-0.33188-1.16871-0.25833.h5
# 23/23 [==============================] - 63s 3s/step - loss: 1.3559 - categorical_accuracy: 0.3319 - val_loss: 1.1687 - val_categorical_accuracy: 0.2583 - lr: 0.0020
# Epoch 2/50
# 23/23 [==============================] - ETA: 0s - loss: 1.3157 - categorical_accuracy: 0.3464
# Epoch 00002: saving model to model_init_2023-08-0717_42_21.195077/model-00002-1.31571-0.34638-1.17697-0.22500.h5
# 23/23 [==============================] - 61s 3s/step - loss: 1.3157 - categorical_accuracy: 0.3464 - val_loss: 1.1770 - val_categorical_accuracy: 0.2250 - lr: 0.0020
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 1.2839 - categorical_accuracy: 0.3638
# Epoch 00003: saving model to model_init_2023-08-0717_42_21.195077/model-00003-1.28390-0.36377-1.18058-0.26667.h5
# 23/23 [==============================] - 62s 3s/step - loss: 1.2839 - categorical_accuracy: 0.3638 - val_loss: 1.1806 - val_categorical_accuracy: 0.2667 - lr: 0.0020
# Epoch 4/50
# 23/23 [==============================] - ETA: 0s - loss: 1.2615 - categorical_accuracy: 0.3870
# Epoch 00004: saving model to model_init_2023-08-0717_42_21.195077/model-00004-1.26151-0.38696-1.10774-0.26667.h5
# 23/23 [==============================] - 60s 3s/step - loss: 1.2615 - categorical_accuracy: 0.3870 - val_loss: 1.1077 - val_categorical_accuracy: 0.2667 - lr: 0.0020
# Epoch 5/50
# 23/23 [==============================] - ETA: 0s - loss: 1.
h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.8342 - categorical_accuracy: 0.5681 - val_loss: 1.2720 - val_categorical_accuracy: 0.3083 - lr: 0.0010
# Epoch 31/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8454 - categorical_accuracy: 0.5797
# Epoch 00031: saving model to model_init_2023-08-0717_42_21.195077/model-00031-0.84540-0.57971-1.29755-0.36667.h5
# 23/23 [==============================] - 64s 3s/step - loss: 0.8454 - categorical_accuracy: 0.5797 - val_loss: 1.2976 - val_categorical_accuracy: 0.3667 - lr: 0.0010
# Epoch 32/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8258 - categorical_accuracy: 0.6000
# Epoch 00032: saving model to model_init_2023-08-0717_42_21.195077/model-00032-0.82577-0.60000-1.25709-0.35833.h5
# 23/23 [==============================] - 61s 3s/step - loss: 0.8258 - categorical_accuracy: 0.6000 - val_loss: 1.2571 - val_categorical_accuracy: 0.3583 - lr: 0.0010
# Epoch 33/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8339 - categorical_accuracy: 0.5725
# Epoch 00033: saving model to model_init_2023-08-0717_42_21.195077/model-00033-0.83394-0.57246-1.37394-0.50833.h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.8339 - categorical_accuracy: 0.5725 - val_loss: 1.3739 - val_categorical_accuracy: 0.5083 - lr: 0.0010
# Epoch 34/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8052 - categorical_accuracy: 0.5913
# Epoch 00034: saving model to model_init_2023-08-0717_42_21.195077/model-00034-0.80516-0.59130-1.43259-0.55833.h5
# 23/23 [==============================] - 61s 3s/step - loss: 0.8052 - categorical_accuracy: 0.5913 - val_loss: 1.4326 - val_categorical_accuracy: 0.5583 - lr: 0.0010
# Epoch 35/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8218 - categorical_accuracy: 0.6014
# Epoch 00035: saving model to model_init_2023-08-0717_42_21.195077/model-00035-0.82177-0.60145-1.14693-0.53333.h5
# 23/23 [==============================] - 62s 3s/step - loss: 0.8218 - categorical_accuracy: 0.6014 - val_loss: 1.1469 - val_categorical_accuracy: 0.5333 - lr: 0.0010
# Epoch 36/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8278 - categorical_accuracy: 0.5913
# Epoch 00036: saving model to model_init_2023-08-0717_42_21.195077/model-00036-0.82779-0.59130-1.17066-0.54167.h5
# 23/23 [==============================] - 60s 3s/step - loss: 0.8278 - categorical_accuracy: 0.5913 - val_loss: 1.1707 - val_categorical_accuracy: 0.5417 - lr: 0.0010
# Epoch 37/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8331 - categorical_accuracy: 0.5783
# Epoch 00037: saving model to model_init_2023-08-0717_42_21.195077/model-00037-0.83305-0.57826-1.33071-0.52500.h5
# 23/23 [==============================] - 62s 3s/step - loss: 0.8331 - categorical_accuracy: 0.5783 - val_loss: 1.3307 - val_categorical_accuracy: 0.5250 - lr: 0.0010
# Epoch 38/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8403 - categorical_accuracy: 0.6058
# Epoch 00038: saving model to model_init_2023-08-0717_42_21.195077/model-00038-0.84035-0.60580-1.31204-0.50833.h5
# 23/23 [==============================] - 62s 3s/step - loss: 0.8403 - categorical_accuracy: 0.6058 - val_loss: 1.3120 - val_categorical_accuracy: 0.5083 - lr: 0.0010
# Epoch 39/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8140 - categorical_accuracy: 0.6072
# Epoch 00039: saving model to model_init_2023-08-0717_42_21.195077/model-00039-0.81405-0.60725-1.17253-0.54167.h5
# 23/23 [==============================] - 63s 3s/step - loss: 0
h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.7579 - categorical_accuracy: 0.6232 - val_loss: 1.1047 - val_categorical_accuracy: 0.5583 - lr: 0.0010
# Epoch 48/50
# 23/23 [==============================] - ETA: 0s - loss: 0.7518 - categorical_accuracy: 0.6507
# Epoch 00048: saving model to model_init_2023-08-0717_42_21.195077/model-00048-0.75183-0.65072-1.52708-0.51667.h5
# 23/23 [==============================] - 60s 3s/step - loss: 0.7518 - categorical_accuracy: 0.6507 - val_loss: 1.5271 - val_categorical_accuracy: 0.5167 - lr: 0.0010
# Epoch 49/50
# 23/23 [==============================] - ETA: 0s - loss: 0.7404 - categorical_accuracy: 0.6493
# Epoch 00049: saving model to model_init_2023-08-0717_42_21.195077/model-00049-0.74039-0.64928-1.52532-0.55000.h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.7404 - categorical_accuracy: 0.6493 - val_loss: 1.5253 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 50/50
# 23/23 [==============================] - ETA: 0s - loss: 0.6862 - categorical_accuracy: 0.6826
# Epoch 00050: saving model to model_init_2023-08-0717_42_21.195077/model-00050-0.68615-0.68261-1.11482-0.60833.h5
# 23/23 [==============================] - 63s 3s/step - loss: 0.6862 - categorical_accuracy: 0.6826 - val_loss: 1.1148 - val_categorical_accuracy: 0.6083 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %% [markdown]
# ### Insights
# - Cleary we got better results 69%  and 61% on traning and validation
# - let's try changing conv and RNN layers to check if it improves

# %% [markdown]
# ### Model 4 with CNN + RNN + GRU with less batchsize and epoch

# %%
input_shape = (len(images_sequence), dim_x, dim_y, 3)

#write your model here
model = Sequential()
model.add(TimeDistributed(
     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
 )
model.add(TimeDistributed(
     MaxPooling2D((2,2)))
 )
model.add(BatchNormalization())

model.add(TimeDistributed(
     Conv2D(64, (3,3), activation='relu'))
 )
model.add(TimeDistributed(
     MaxPooling2D((2,2)))
 )
model.add(BatchNormalization())
model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(BatchNormalization())
model.add(GRU(128))
model.add(Dropout(0.25))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %%
optimiser = tf.optimizers.Adam(lr=0.01)#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_6 (TimeDis  (None, 12, 118, 118, 32)  896
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 12, 59, 59, 32)   0
#  tributed)
#
#  batch_normalization_4 (Batc  (None, 12, 59, 59, 32)   128
#  hNormalization)
#
#  time_distributed_8 (TimeDis  (None, 12, 57, 57, 64)   18496
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 12, 28, 28, 64)   0
#  tributed)
#
#  batch_normalization_5 (Batc  (None, 12, 28, 28, 64)   256
#  hNormalization)
#
#  time_distributed_10 (TimeDi  (None, 12, 64)           0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 12, 64)           4160
#  stributed)
#
#  batch_normalization_6 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  gru_1 (GRU)                 (None, 128)               74496
#
#  dropout (Dropout)           (None, 128)               0
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 99,845
# Trainable params: 99,269
# Non-trainable params: 576
# _________________________________________________________________
# None

# %%
batch_size = 20
num_epochs = 20
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 20
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.6432 - categorical_accuracy: 0.3544Source path =  /home/datasets/Project_data/val ; batch size = 20
#
# Epoch 00001: saving model to model_init_2023-08-0717_42_21.195077/model-00001-1.64319-0.35441-2.93397-0.23000.h5
# 34/34 [==============================] - 66s 2s/step - loss: 1.6432 - categorical_accuracy: 0.3544 - val_loss: 2.9340 - val_categorical_accuracy: 0.2300 - lr: 0.0100
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.2527 - categorical_accuracy: 0.4118
# Epoch 00002: saving model to model_init_2023-08-0717_42_21.195077/model-00002-1.25267-0.41176-3.40833-0.19000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.2527 - categorical_accuracy: 0.4118 - val_loss: 3.4083 - val_categorical_accuracy: 0.1900 - lr: 0.0100
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1422 - categorical_accuracy: 0.4779
# Epoch 00003: saving model to model_init_2023-08-0717_42_21.195077/model-00003-1.14222-0.47794-2.50290-0.19000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 1.1422 - categorical_accuracy: 0.4779 - val_loss: 2.5029 - val_categorical_accuracy: 0.1900 - lr: 0.0100
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1159 - categorical_accuracy: 0.4971
# Epoch 00004: saving model to model_init_2023-08-0717_42_21.195077/model-00004-1.11592-0.49706-1.65783-0.35000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 1.1159 - categorical_accuracy: 0.4971 - val_loss: 1.6578 - val_categorical_accuracy: 0.3500 - lr: 0.0100
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0809 - categorical_accuracy: 0.4838
# Epoch 00005: saving model to model_init_2023-08-0717_42_21.195077/model-00005-1.08092-0.48382-1.63953-0.38000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.0809 - categorical_accuracy: 0.4838 - val_loss: 1.6395 - val_categorical_accuracy: 0.3800 - lr: 0.0100
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0005 - categorical_accuracy: 0.4985
# Epoch 00006: saving model to model_init_2023-08-0717_42_21.195077/model-00006-1.00050-0.49853-1.38960-0.38000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.0005 - categorical_accuracy: 0.4985 - val_loss: 1.3896 - val_categorical_accuracy: 0.3800 - lr: 0.0100
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1002 - categorical_accuracy: 0.5000
# Epoch 00007: saving model to model_init_2023-08-0717_42_21.195077/model-00007-1.10021-0.50000-1.91593-0.26000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.1002 - categorical_accuracy: 0.5000 - val_loss: 1.9159 - val_categorical_accuracy: 0.2600 - lr: 0.0100
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0510 - categorical_accuracy: 0.5353
# Epoch 00008: saving model to model_init_2023-08-0717_42_21.195077/model-00008-1.05099-0.53529-1.39314-0.41000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 1.0510 - categorical_accuracy: 0.5353 - val_loss: 1.3931 - val_categorical_accuracy: 0.4100 - lr: 0.0100
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0149 - categorical_accuracy: 0.5397
# Epoch 00009: saving model to model_init_2023-08-0717_42_21.195077/model-00009-1.01488-0.53971-1.96543-0.30000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.0149 - categorical_accuracy: 0.5397 - val_loss: 1.9654 - val_categorical_accuracy: 0.3000 - lr: 0.0100
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9350 - categorical_accuracy: 0.5721
# Epoch 00010: saving model to model_init_2023-08-0717_42_21.195077/model-00010-0.93501-0.57206-1.88391-0.41000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 0.9350 - categorical_accuracy: 0.5721 - val_loss: 1.8839 - val_categorical_accuracy: 0.4100 - lr: 0.0100
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8851 - categorical_accuracy: 0.5882
# Epoch 00011: saving model to model_init_2023-08-0717_42_21.195077/model-00011-0.88515-0.58824-2.84079-0.29000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 34/34 [==============================] - 62s 2s/step - loss: 0.8851 - categorical_accuracy: 0.5882 - val_loss: 2.8408 - val_categorical_accuracy: 0.2900 - lr: 0.0100
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8256 - categorical_accuracy: 0.6103
# Epoch 00012: saving model to model_init_2023-08-0717_42_21.195077/model-00012-0.82557-0.61029-2.11411-0.39000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 0.8256 - categorical_accuracy: 0.6103 - val_loss: 2.1141 - val_categorical_accuracy: 0.3900 - lr: 0.0020
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8006 - categorical_accuracy: 0.6368
# Epoch 00013: saving model to model_init_2023-08-0717_42_21.195077/model-00013-0.80064-0.63676-1.93912-0.38000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 0.8006 - categorical_accuracy: 0.6368 - val_loss: 1.9391 - val_categorical_accuracy: 0.3800 - lr: 0.0020
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7182 - categorical_accuracy: 0.6868
# Epoch 00014: saving model to model_init_2023-08-0717_42_21.195077/model-00014-0.71824-0.68676-1.75586-0.44000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 0.7182 - categorical_accuracy: 0.6868 - val_loss: 1.7559 - val_categorical_accuracy: 0.4400 - lr: 0.0020
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7196 - categorical_accuracy: 0.6926
# Epoch 00015: saving model to model_init_2023-08-0717_42_21.195077/model-00015-0.71958-0.69265-1.72266-0.47000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 0.7196 - categorical_accuracy: 0.6926 - val_loss: 1.7227 - val_categorical_accuracy: 0.4700 - lr: 0.0020
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6949 - categorical_accuracy: 0.6985
# Epoch 00016: saving model to model_init_2023-08-0717_42_21.195077/model-00016-0.69493-0.69853-1.98363-0.38000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
# 34/34 [==============================] - 60s 2s/step - loss: 0.6949 - categorical_accuracy: 0.6985 - val_loss: 1.9836 - val_categorical_accuracy: 0.3800 - lr: 0.0020
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6733 - categorical_accuracy: 0.7162
# Epoch 00017: saving model to model_init_2023-08-0717_42_21.195077/model-00017-0.67325-0.71618-1.33652-0.52000.h5
# 34/34 [==============================] - 60s 2s/step - loss: 0.6733 - categorical_accuracy: 0.7162 - val_loss: 1.3365 - val_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6050 - categorical_accuracy: 0.7382
# Epoch 00018: saving model to model_init_2023-08-0717_42_21.195077/model-00018-0.60502-0.73824-1.03880-0.57000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 0.6050 - categorical_accuracy: 0.7382 - val_loss: 1.0388 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6236 - categorical_accuracy: 0.7176
# Epoch 00019: saving model to model_init_2023-08-0717_42_21.195077/model-00019-0.62360-0.71765-1.08627-0.60000.h5
# 34/34 [==============================] - 60s 2s/step - loss: 0.6236 - categorical_accuracy: 0.7176 - val_loss: 1.0863 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5881 - categorical_accuracy: 0.7294
# Epoch 00020: saving model to model_init_2023-08-0717_42_21.195077/model-00020-0.58814-0.72941-0.93977-0.60000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 0.5881 - categorical_accuracy: 0.7294 - val_loss: 0.9398 - val_categorical_accuracy: 0.6000 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %% [markdown]
# ### Insights
# - Cleary we got better results 72%  and 60% on traning and validation
# - let's try changing to LSTM with has more trainable parameters

# %% [markdown]
# ### Model 5 with CNN+ RNN+ LSTM

# %%
model = Sequential()
model.add(TimeDistributed(
     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
 )
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Flatten()))

model.add(LSTM(128))
model.add(Dropout(0.25))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(5, activation='softmax'))

# %%
optimiser = tf.optimizers.Adam(lr=0.01)#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_6 (TimeDis  (None, 12, 118, 118, 32)  896
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 12, 118, 118, 32)  128
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 12, 59, 59, 32)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 12, 111392)       0
#  tributed)
#
#  lstm (LSTM)                 (None, 128)               57098752
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 57,116,933
# Trainable params: 57,116,869
# Non-trainable params: 64
# _________________________________________________________________
# None

# %%
batch_size = 20
num_epochs = 20
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 20
# Epoch 1/20
# 2023-08-07 19:43:12.796615: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 34/34 [==============================] - ETA: 0s - loss: 1.6161 - categorical_accuracy: 0.2912Source path =  /home/datasets/Project_data/val ; batch size = 20
#
# Epoch 00001: saving model to model_init_2023-08-0719_42_28.262063/model-00001-1.61606-0.29118-2.00621-0.18000.h5
# 34/34 [==============================] - 65s 2s/step - loss: 1.6161 - categorical_accuracy: 0.2912 - val_loss: 2.0062 - val_categorical_accuracy: 0.1800 - lr: 0.0100
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4383 - categorical_accuracy: 0.3162
# Epoch 00002: saving model to model_init_2023-08-0719_42_28.262063/model-00002-1.43833-0.31618-2.12650-0.20000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 1.4383 - categorical_accuracy: 0.3162 - val_loss: 2.1265 - val_categorical_accuracy: 0.2000 - lr: 0.0100
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4171 - categorical_accuracy: 0.3588
# Epoch 00003: saving model to model_init_2023-08-0719_42_28.262063/model-00003-1.41706-0.35882-2.07166-0.22000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.4171 - categorical_accuracy: 0.3588 - val_loss: 2.0717 - val_categorical_accuracy: 0.2200 - lr: 0.0100
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4270 - categorical_accuracy: 0.3338
# Epoch 00004: saving model to model_init_2023-08-0719_42_28.262063/model-00004-1.42701-0.33382-2.40212-0.17000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.4270 - categorical_accuracy: 0.3338 - val_loss: 2.4021 - val_categorical_accuracy: 0.1700 - lr: 0.0100
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3988 - categorical_accuracy: 0.3868
# Epoch 00005: saving model to model_init_2023-08-0719_42_28.262063/model-00005-1.39884-0.38676-2.00122-0.21000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.3988 - categorical_accuracy: 0.3868 - val_loss: 2.0012 - val_categorical_accuracy: 0.2100 - lr: 0.0100
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3937 - categorical_accuracy: 0.3735
# Epoch 00006: saving model to model_init_2023-08-0719_42_28.262063/model-00006-1.39366-0.37353-2.48840-0.15000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.3937 - categorical_accuracy: 0.3735 - val_loss: 2.4884 - val_categorical_accuracy: 0.1500 - lr: 0.0100
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4595 - categorical_accuracy: 0.3544
# Epoch 00007: saving model to model_init_2023-08-0719_42_28.262063/model-00007-1.45954-0.35441-2.32485-0.15000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.4595 - categorical_accuracy: 0.3544 - val_loss: 2.3249 - val_categorical_accuracy: 0.1500 - lr: 0.0100
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 1.6856 - categorical_accuracy: 0.3324
# Epoch 00008: saving model to model_init_2023-08-0719_42_28.262063/model-00008-1.68564-0.33235-1.81207-0.17000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.6856 - categorical_accuracy: 0.3324 - val_loss: 1.8121 - val_categorical_accuracy: 0.1700 - lr: 0.0100
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4696 - categorical_accuracy: 0.3412
# Epoch 00009: saving model to model_init_2023-08-0719_42_28.262063/model-00009-1.46962-0.34118-1.77518-0.20000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 1.4696 - categorical_accuracy: 0.3412 - val_loss: 1.7752 - val_categorical_accuracy: 0.2000 - lr: 0.0100
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 1.5234 - categorical_accuracy: 0.3456
# Epoch 00010: saving model to model_init_2023-08-0719_42_28.262063/model-00010-1.52343-0.34559-1.80660-0.18000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.5234 - categorical_accuracy: 0.3456 - val_loss: 1.8066 - val_categorical_accuracy: 0.1800 - lr: 0.0100
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 1.5514 - categorical_accuracy: 0.3250
# Epoch 00011: saving model to model_init_2023-08-0719_42_28.262063/model-00011-1.55140-0.32500-1.73148-0.32000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.5514 - categorical_accuracy: 0.3250 - val_loss: 1.7315 - val_categorical_accuracy: 0.3200 - lr: 0.0100
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 1.5421 - categorical_accuracy: 0.3294
# Epoch 00012: saving model to model_init_2023-08-0719_42_28.262063/model-00012-1.54215-0.32941-1.82996-0.25000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.5421 - categorical_accuracy: 0.3294 - val_loss: 1.8300 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 1.6148 - categorical_accuracy: 0.3265
# Epoch 00013: saving model to model_init_2023-08-0719_42_28.262063/model-00013-1.61483-0.32647-1.62971-0.35000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 1.6148 - categorical_accuracy: 0.3265 - val_loss: 1.6297 - val_categorical_accuracy: 0.3500 - lr: 0.0100
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 1.5925 - categorical_accuracy: 0.3221
# Epoch 00014: saving model to model_init_2023-08-0719_42_28.262063/model-00014-1.59255-0.32206-2.04483-0.28000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.5925 - categorical_accuracy: 0.3221 - val_loss: 2.0448 - val_categorical_accuracy: 0.2800 - lr: 0.0100
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 1.7725 - categorical_accuracy: 0.3368
# Epoch 00015: saving model to model_init_2023-08-0719_42_28.262063/model-00015-1.77253-0.33676-1.67579-0.35000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.7725 - categorical_accuracy: 0.3368 - val_loss: 1.6758 - val_categorical_accuracy: 0.3500 - lr: 0.0100
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 1.8418 - categorical_accuracy: 0.3074
# Epoch 00016: saving model to model_init_2023-08-0719_42_28.262063/model-00016-1.84181-0.30735-1.58984-0.30000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 1.8418 - categorical_accuracy: 0.3074 - val_loss: 1.5898 - val_categorical_accuracy: 0.3000 - lr: 0.0100
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 1.7917 - categorical_accuracy: 0.3279
# Epoch 00017: saving model to model_init_2023-08-0719_42_28.262063/model-00017-1.79171-0.32794-1.67016-0.21000.h5
# 34/34 [==============================] - 63s 2s/step - loss: 1.7917 - categorical_accuracy: 0.3279 - val_loss: 1.6702 - val_categorical_accuracy: 0.2100 - lr: 0.0100
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 1.8677 - categorical_accuracy: 0.3250
# Epoch 00018: saving model to model_init_2023-08-0719_42_28.262063/model-00018-1.86770-0.32500-1.90466-0.22000.h5
# 34/34 [==============================] - 62s 2s/step - loss: 1.8677 - categorical_accuracy: 0.3250 - val_loss: 1.9047 - val_categorical_accuracy: 0.2200 - lr: 0.0100
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 1.8112 - categorical_accuracy: 0.3353
# Epoch 00019: saving model to model_init_2023-08-0719_42_28.262063/model-00019-1.81118-0.33529-1.71173-0.21000.h5
# 34/34 [==============================] - 60s 2s/step - loss: 1.8112 - categorical_accuracy: 0.3353 - val_loss: 1.7117 - val_categorical_accuracy: 0.2100 - lr: 0.0100
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 1.8843 - categorical_accuracy: 0.3162
# Epoch 00020: saving model to model_init_2023-08-0719_42_28.262063/model-00020-1.88425-0.31618-1.62173-0.34000.h5
# 34/34 [==============================] - 61s 2s/step - loss: 1.8843 - categorical_accuracy: 0.3162 - val_loss: 1.6217 - val_categorical_accuracy: 0.3400 - lr: 0.0100

# %% [markdown]
# ### Insights
# - using LSTM got only 31% accuracy on traning data and 34% on valication accuracy

# %% [markdown]
# #### model-00020-0.58814-0.72941-0.93977-0.60000.h5 has best model out of all trained models
#
# #### which comes from the Model 4 with CNN + RNN + GRU with less batchsize and epoch if we can increase epoch and batch size accuaracy might increased
#
# #### (Training Accuracy : 73%, Validation Accuracy : 62%)
